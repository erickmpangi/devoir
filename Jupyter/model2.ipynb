# %%
import pandas as pd
import numpy as np
datos= pd.read_csv('/home/erick-mpangi/Documents/exerices-python/Jupyter/API_SP.DYN.TFRT.IN_DS2_fr_csv_v2_105776/API_SP.DYN.TFRT.IN_DS2_fr_csv_v2_105776.csv')

# %%
datos.head()
# Out:
#   Country Name Country Code                                   Indicator Name  \
# 0        Aruba          ABW  Taux de fertilité, total (naissances par femme)
# 1          NaN          AFE  Taux de fertilité, total (naissances par femme)
# 2  Afghanistan          AFG  Taux de fertilité, total (naissances par femme)
# 3          NaN          AFW  Taux de fertilité, total (naissances par femme)
# 4       Angola          AGO  Taux de fertilité, total (naissances par femme)
#
#    Indicator Code      1960      1961      1962      1963      1964      1965  \
# 0  SP.DYN.TFRT.IN  4.567000  4.422000  4.262000  4.107000  3.940000  3.797000
# 1  SP.DYN.TFRT.IN  6.650330  6.667308  6.688246  6.709226  6.724930  6.737459
# 2  SP.DYN.TFRT.IN  7.282000  7.284000  7.292000  7.302000  7.304000  7.305000
# 3  SP.DYN.TFRT.IN  6.468887  6.478351  6.492277  6.500229  6.516739  6.532766
# 4  SP.DYN.TFRT.IN  6.708000  6.790000  6.872000  6.954000  7.036000  7.116000
#
# ...
