# %%
import pandas as pd
datos = pd.read_csv('/home/erick-mpangi/Documents/exerices-python/Jupyter/API_IT.NET.USER.ZS_DS2_fr_csv_v2_92392/API_IT.NET.USER.ZS_DS2_fr_csv_v2_92392.csv')

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 69 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    264 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   1960            0 non-null      float64
#  5   1961            0 non-null      float64
#  6   1962            0 non-null      float64
#  7   1963            0 non-null      float64
#  8   1964            0 non-null      float64
#  9   1965            0 non-null      float64
#  10  1966            0 non-null      float64
#  11  1967            0 non-null      float64
#  12  1968            0 non-null      float64
#  13  1969            0 non-null      float64
#  14  1970            0 non-null      float64
#  15  1971            0 non-null      float64
#  16  1972            0 non-null      float64
# ...

# %%
datos.head()
# Out:
#   Country Name Country Code                                Indicator Name  \
# 0        Aruba          ABW  Utilisateurs d Internet (% de la population)
# 1          NaN          AFE  Utilisateurs d Internet (% de la population)
# 2  Afghanistan          AFG  Utilisateurs d Internet (% de la population)
# 3          NaN          AFW  Utilisateurs d Internet (% de la population)
# 4       Angola          AGO  Utilisateurs d Internet (% de la population)
#
#    Indicator Code  1960  1961  1962  1963  1964  1965  ...   2015  2016  2017  \
# 0  IT.NET.USER.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...  88.70  93.5  97.2
# 1  IT.NET.USER.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN   NaN   NaN
# 2  IT.NET.USER.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...   8.26  11.0  13.5
# 3  IT.NET.USER.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN   NaN   NaN
# 4  IT.NET.USER.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...  22.00  23.2  26.0
#
#    2018  2019  2020  2021  2022  2023  2024
# ...

# %%
#datos = datos[['1960', '1989']].dropna()

# %%
datos = datos.drop(columns=['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989'])

# %%
datos.head()
# Out:
#           Country Name Country Code  \
# 2          Afghanistan          AFG
# 4               Angola          AGO
# 5              Albanie          ALB
# 6              Andorre          AND
# 8  Émirats arabes unis          ARE
#
#                                  Indicator Name  Indicator Code  1990  1991  \
# 2  Utilisateurs d Internet (% de la population)  IT.NET.USER.ZS   0.0   NaN
# 4  Utilisateurs d Internet (% de la population)  IT.NET.USER.ZS   0.0   NaN
# 5  Utilisateurs d Internet (% de la population)  IT.NET.USER.ZS   0.0   NaN
# 6  Utilisateurs d Internet (% de la population)  IT.NET.USER.ZS   0.0   NaN
# 8  Utilisateurs d Internet (% de la population)  IT.NET.USER.ZS   0.0   NaN
#
#    1992  1993  1994    1995  ...   2015  2016  2017  2018  2019   2020   2021  \
# 2   NaN   NaN   NaN     NaN  ...   8.26  11.0  13.5  16.8  17.6   17.0   16.5
# 4   NaN   NaN   NaN     NaN  ...  22.00  23.2  26.0  29.0  32.1   36.6   39.4
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sb

plt.figure(figsize=(20, 6))  # Largeur augmentée
sb.scatterplot(x=datos['Country Code'], y=datos['2023'], hue=datos['Indicator Name'])
plt.xticks(rotation=45, ha='right')  # Rotation des labels x
plt.tight_layout()  # Ajuste automatiquement la disposition
plt.show()

# %%
import numpy as np

# %%
# Filtrer les pays avec des valeurs manquantes
datos = datos[datos['2020'].notna()]
# Créer un graphique à barres
plt.figure(figsize=(16, 8))
sb.barplot(x=datos['Country Name'], y=datos['2020'], hue=datos['Indicator Name'])
plt.xticks(rotation=45, ha='right')
# Définir des graduations régulières sur l'axe y
y_min = datos['2020'].min()
y_max = datos['2020'].max()
plt.yticks(np.linspace(y_min, y_max, num=10))  # 10 graduations régulières
plt.tight_layout()
plt.show()

# %%
datos_na = datos.select_dtypes(include=['float64', 'int64'])  # ou include='number'
sb.set(rc={'figure.figsize': (25, 8)})
sb.heatmap(datos_na.corr(), annot=True, cmap="coolwarm")
# Out:
# <Axes: >

# %%
country="Congo, République démocratique du"
data_country = datos[datos['Country Name'] == country]
columns = [col for col in datos.columns if col.strip().isdigit()]
year=list(map(int, columns))

population=data_country[columns].iloc[0]

df_plot = pd.DataFrame({
    'Année': list(map(int, year)),
    'Valeur': population.values
})

# %%
plt.figure(figsize=(16, 6))
plt.plot(df_plot['Année'], df_plot['Valeur'], marker='o', linestyle='-')
plt.title(f"Évolution de l'indicateur pour {country}")
plt.xlabel("Year")
plt.ylabel("Population")
plt.xticks(year, rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Filtrer les pays avec des valeurs manquantes# Créer un graphique à barres
plt.figure(figsize=(16, 8))
sb.barplot(x= year, y= population, hue=['Population with access to internet']*len(year))
plt.xticks(rotation=45, ha='right')
# Définir des graduations régulières sur l'axe y
y_min = population.min()
y_max = population.max()
plt.yticks(np.linspace(y_min, y_max, num=10))  # 10 graduations régulières
plt.tight_layout()
plt.show()

# %%
country="Congo, République du"
data_country = datos[datos['Country Name'] == country]
data_na=data_country.select_dtypes(include=['float64', 'int64'])  # ou include='number'
df_corr = data_na.T
sb.set(rc={'figure.figsize': (25, 8)})
sb.heatmap(df_corr.corr(), annot=True, cmap="coolwarm")
plt.title(f"Corrélation des indicateurs pour {country}")
plt.show()
